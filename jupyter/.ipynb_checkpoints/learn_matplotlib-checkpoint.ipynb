# %%
# %config IPCompleter.greedy=True
# %matplotlib inline

# %%
import pandas as pd, numpy as np, os, sys
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from IPython.display import display, HTML
from IPython.core.debugger import Tracer
from IPython.core.debugger import Pdb

font = {'size'   : 18}
matplotlib.rc('font', **font)

def plotHorizontalBars(series, xlabel, title):
    xpos = np.arange(len(series.index), 0, -1)
    plt.barh(xpos, series, align='center', alpha=0.5, color='g')
    plt.grid(axis='x')
    plt.yticks(xpos, series.index)
    plt.xlabel(xlabel)
    plt.title(title)

def plotVerticalBars(series, ylabel, title):
    xpos = np.arange(len(series.index), 0, -1)
    plt.bar(xpos, series, align='center', alpha=0.5, color='g')
    plt.grid(axis='y')
    plt.xticks(xpos, series.index)
    plt.ylabel(ylabel)
    plt.title(title)

def greaterThanProbs(x, y, binSize, positiveClass=True, minx=None, maxx=None, minCnt=20):
    """
    both x is numeric and y is categorical. returns y's probabilities in each x bin
    """
    assert(y is not None)
    
    binDF = pd.concat([x,y], axis=1, ignore_index=True)
    binDF.columns = ['x', 'y']
    if minx is None:
        minx = binDF.x.min()
    if maxx is None:
        maxx = binDF.x.max()

    minx, maxx = [minx, maxx]
    bins = np.arange(minx, maxx*1.0001, binSize)
    rsDF = pd.DataFrame(bins, columns=[x.name])
    rsDF['bucket'] = '>= '
    rsDF['bucket'] = rsDF.bucket.map(str) + rsDF[x.name].map(lambda x: '{:.3f}'.format(x))

    freqCol = 'freq'
    rsDF[freqCol] = [binDF.loc[binDF.x >= thresh, 'y'].shape[0] for thresh in bins]
    rsDF['freq_pct'] = rsDF[freqCol]/x.shape[0]
    
    def prob(threshold):
        aa = binDF[binDF.x >= threshold]
        if aa.shape[0] == 0:
            return 0.0
        
        aaPos = binDF[binDF.y == positiveClass]
        return float(aaPos.shape[0])/float(aa.shape[0])

    rsDF['prob'] = [prob(thresh) for thresh in bins]
    
    rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
    return rsDF

def greaterThanProbs(x, y, binSize, positiveClass=True, minx=None, maxx=None, minCnt=20):
    """
    both x is numeric and y is categorical. returns y's probabilities in each x bin
    """
    assert(y is not None)
    
    binDF = pd.concat([x,y], axis=1, ignore_index=True)
    binDF.columns = ['x', 'y']
    if minx is None:
        minx = binDF.x.min()
    if maxx is None:
        maxx = binDF.x.max()

    minx, maxx = [minx, maxx]
    bins = np.arange(minx, maxx*1.0001, binSize)
    rsDF = pd.DataFrame(bins, columns=[x.name])
    rsDF['bucket'] = '>= '
    rsDF['bucket'] = rsDF.bucket.map(str) + rsDF[x.name].map(lambda x: '{:.3f}'.format(x))

    freqCol = 'freq'
    rsDF[freqCol] = [binDF.loc[binDF.x >= thresh, 'y'].shape[0] for thresh in bins]
    rsDF['freq_pct'] = rsDF[freqCol]/x.shape[0]
    
    def prob(threshold):
        aa = binDF[binDF.x >= threshold]
        if aa.shape[0] == 0:
            return 0.0
        
        aaPos = binDF[binDF.y == positiveClass]
        return float(aaPos.shape[0])/float(aa.shape[0])

    rsDF['prob'] = [prob(thresh) for thresh in bins]
    
    rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
    return rsDF

def greaterThanStats(x, y, binSize, minx=None, maxx=None, minCnt=20):
    """
    both x and y are numeric. If y = None, y will be set to x
    """
    if y is None:
        y = x
    binDF = pd.concat([x,y], axis=1, ignore_index=True)
    binDF.columns = ['x', 'y']
    if minx is None:
        minx = binDF.x.min()
    if maxx is None:
        maxx = binDF.x.max()

    minx, maxx = [minx, maxx]
    bins = np.arange(minx, maxx*1.0001, binSize)
    rsDF = pd.DataFrame(bins, columns=[x.name])
    rsDF['bucket'] = '>= ' + rsDF[x.name]

    freqCol = 'freq'
    rsDF[freqCol] = [binDF.loc[binDF.x >= thresh, 'y'].shape[0] for thresh in bins]
    rsDF['freq_pct'] = rsDF[freqCol]/x.shape[0]

    meanCol = '{}_mean'.format(y.name)
    rsDF[meanCol] = [np.mean(binDF.loc[binDF.x >= thresh, 'y']) for thresh in bins]

    sumCol = '{}_sum'.format(y.name)
    rsDF[sumCol] = [np.sum(binDF.loc[binDF.x >= thresh, 'y']) for thresh in bins]
    totY = y.sum()
    rsDF['sum_pct'] = rsDF[sumCol]/totY
    
    rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
    return rsDF

def lessThanStats(x, y, binSize, minx=None, maxx=None, minCnt=20):
    """
    both x and y are numeric. If y = None, y will be set to x
    """
    if y is None:
        y = x
    binDF = pd.concat([x,y], axis=1, ignore_index=True)
    binDF.columns = ['x', 'y']
    if minx is None:
        minx = binDF.x.min()
    if maxx is None:
        maxx = binDF.x.max()

    bins = np.arange(maxx, minx, -binSize)
    rsDF = pd.DataFrame(bins, columns=[x.name])

    freqCol = 'freq'
    rsDF[freqCol] = [binDF.loc[binDF.x <= thresh, 'y'].shape[0] for thresh in bins]
    rsDF['freq_pct'] = rsDF[freqCol]/x.shape[0]

    meanCol = '{}_mean'.format(y.name)
    rsDF[meanCol] = [np.mean(binDF.loc[binDF.x <= thresh, 'y']) for thresh in bins]

    sumCol = '{}_sum'.format(y.name)
    rsDF[sumCol] = [np.sum(binDF.loc[binDF.x <= thresh, 'y']) for thresh in bins]
    totY = y.sum()
    rsDF['sum_pct'] = rsDF[sumCol]/totY
    
    rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
    return rsDF

# %%
# %%time
cacheDir = '/Users/huiwang/dev/PTG_DataScience/spark_cache'
inFile = '{}/desktop_profile_complete_TY2015.csv'.format(cacheDir)
allData = pd.read_csv(inFile)
# Out:
# CPU times: user 11.4 s, sys: 740 ms, total: 12.2 s
# Wall time: 12.2 s

# %%
display(allData.shape)
a = allData.PRODUCT_GROUP + ' - ' + allData.PRODUCT_SEGMENT
a = a.value_counts().sort_index()
plt.figure(figsize=(16,12))
plotHorizontalBars(a, 'CANs', 'CANs by Product Segments')
# Out:
# (96329, 571)

# %%
df = allData[(allData.PRODUCT_GROUP == 'LACERTE') & (allData.PRODUCT_SEGMENT != 'DIAMOND PASSPORT') & (~allData.IS_PM)]
display(df.AT_RISK.value_counts())

plt.figure(figsize=(16,4))
a = df.PRODUCT_SEGMENT.value_counts().sort_index()
plotHorizontalBars(a, 'CANs', 'CANs by Product Segments')
# Out:
# False    14312
# True       652
# Name: AT_RISK, dtype: int64

# %%
a = df.LACERTE_NET_BILL
plt.figure(figsize=(16,6))
plt.hist(a, bins=30, range=[0,30000])
plt.title("{} Distribution".format(a.name))
plt.grid(axis='y')
plt.xlabel(a.name)
plt.ylabel("CANs")

# %%
x = df.LACERTE_NET_BILL
y = df.LACERTE_NET_BILL_DISCOUNT_PCT
stats = lessThanStats(x, y, binSize=1000, minx=0)
a = stats.sort_values(x.name)

plt.figure(figsize=(16,6))
meanCol = y.name + '_mean'
plt.plot(a[x.name], a[meanCol], marker='^')
plt.xlabel(x.name)
plt.ylabel(meanCol)
plt.tight_layout()
plt.show()

display(stats)
# Out:
#     LACERTE_NET_BILL   freq  freq_pct  LACERTE_NET_BILL_DISCOUNT_PCT_mean  \
# 0            60796.5  14964  1.000000                            0.220148
# 1            59796.5  14963  0.999933                            0.220146
# 2            58796.5  14963  0.999933                            0.220146
# 3            57796.5  14963  0.999933                            0.220146
# 4            56796.5  14963  0.999933                            0.220146
# 5            55796.5  14963  0.999933                            0.220146
# 6            54796.5  14963  0.999933                            0.220146
# 7            53796.5  14963  0.999933                            0.220146
# 8            52796.5  14963  0.999933                            0.220146
# 9            51796.5  14963  0.999933                            0.220146
# 10           50796.5  14963  0.999933                            0.220146
# 11           49796.5  14962  0.999866                            0.220140
# 12           48796.5  14962  0.999866                            0.220140
# 13           47796.5  14962  0.999866                            0.220140
# 14           46796.5  14962  0.999866                            0.220140
# 15           45796.5  14962  0.999866                            0.220140
# 16           44796.5  14962  0.999866                            0.220140
# 17           43796.5  14962  0.999866                            0.220140
# 18           42796.5  14962  0.999866                            0.220140
# 19           41796.5  14962  0.999866                            0.220140
# 20           40796.5  14961  0.999800                            0.220143
# 21           39796.5  14959  0.999666                            0.220106
# 22           38796.5  14959  0.999666                            0.220106
# 23           37796.5  14955  0.999399                            0.220101
# 24           36796.5  14954  0.999332                            0.220078
# 25           35796.5  14953  0.999265                            0.220056
# 26           34796.5  14951  0.999131                            0.220057
# 27           33796.5  14948  0.998931                            0.220055
# 28           32796.5  14946  0.998797                            0.220068
# 29           31796.5  14945  0.998730                            0.220074
# ..               ...    ...       ...                                 ...
# 31           29796.5  14941  0.998463                            0.220066
# 32           28796.5  14935  0.998062                            0.220058
# 33           27796.5  14928  0.997594                            0.220021
# 34           26796.5  14927  0.997527                            0.220011
# 35           25796.5  14919  0.996993                            0.220024
# 36           24796.5  14909  0.996325                            0.219963
# 37           23796.5  14901  0.995790                            0.219920
# 38           22796.5  14887  0.994854                            0.219944
# 39           21796.5  14865  0.993384                            0.219879
# 40           20796.5  14833  0.991246                            0.219896
# 41           19796.5  14774  0.987303                            0.220101
# 42           18796.5  14686  0.981422                            0.220285
# 43           17796.5  14553  0.972534                            0.220681
# 44           16796.5  14384  0.961240                            0.221035
# 45           15796.5  14220  0.950281                            0.221252
# 46           14796.5  14003  0.935779                            0.221594
# 47           13796.5  13701  0.915597                            0.222043
# 48           12796.5  13369  0.893411                            0.222511
# 49           11796.5  13007  0.869219                            0.222979
# 50           10796.5  12466  0.833066                            0.223588
# 51            9796.5  11963  0.799452                            0.223365
# 52            8796.5  11393  0.761361                            0.223801
# 53            7796.5  10339  0.690925                            0.226883
# 54            6796.5   9335  0.623831                            0.227331
# 55            5796.5   7918  0.529137                            0.234978
# 56            4796.5   4759  0.318030                            0.282702
# 57            3796.5   2032  0.135793                            0.404384
# 58            2796.5    734  0.049051                            0.529539
# 59            1796.5    198  0.013232                            0.691833
# 60             796.5     74  0.004945                            0.978209
#
#     LACERTE_NET_BILL_DISCOUNT_PCT_sum   sum_pct
# 0                         3294.300005  1.000000
# 1                         3294.050005  0.999924
# 2                         3294.050005  0.999924
# 3                         3294.050005  0.999924
# 4                         3294.050005  0.999924
# 5                         3294.050005  0.999924
# 6                         3294.050005  0.999924
# 7                         3294.050005  0.999924
# 8                         3294.050005  0.999924
# 9                         3294.050005  0.999924
# 10                        3294.050005  0.999924
# 11                        3293.740005  0.999830
# 12                        3293.740005  0.999830
# 13                        3293.740005  0.999830
# 14                        3293.740005  0.999830
# 15                        3293.740005  0.999830
# 16                        3293.740005  0.999830
# 17                        3293.740005  0.999830
# 18                        3293.740005  0.999830
# 19                        3293.740005  0.999830
# 20                        3293.560005  0.999775
# 21                        3292.570005  0.999475
# 22                        3292.570005  0.999475
# 23                        3291.612989  0.999184
# 24                        3291.048741  0.999013
# 25                        3290.498741  0.998846
# 26                        3290.068741  0.998716
# 27                        3289.375581  0.998505
# 28                        3289.139516  0.998434
# 29                        3289.007747  0.998394
# ..                                ...       ...
# 31                        3288.008777  0.998090
# 32                        3286.561006  0.997651
# 33                        3284.471775  0.997017
# 34                        3284.101775  0.996904
# 35                        3282.539110  0.996430
# 36                        3279.421938  0.995484
# 37                        3277.032127  0.994758
# 38                        3274.309346  0.993932
# 39                        3268.505909  0.992170
# 40                        3261.723077  0.990111
# 41                        3251.772131  0.987090
# 42                        3235.103747  0.982031
# 43                        3211.576859  0.974889
# 44                        3179.365430  0.965111
# 45                        3146.200139  0.955044
# 46                        3102.987400  0.941926
# 47                        3042.215617  0.923479
# 48                        2974.754816  0.903001
# 49                        2900.289641  0.880396
# 50                        2787.242492  0.846080
# 51                        2672.120290  0.811134
# 52                        2549.764767  0.773993
# 53                        2345.746505  0.712062
# 54                        2122.138383  0.644185
# 55                        1860.557368  0.564781
# 56                        1345.380614  0.408397
# 57                         821.708452  0.249433
# 58                         388.681312  0.117986
# 59                         136.983013  0.041582
# 60                          72.387466  0.021974
#
# [61 rows x 6 columns]

# %%
x = df.LACERTE_NET_BILL
y = df.ATTEMPTS
stats = lessThanStats(x, y, binSize=1000, minx=0, maxx=20000)
a = stats.sort_values(x.name)

plt.figure(figsize=(16,5))
plt.subplot(131)
meanCol = y.name + '_mean'
plt.plot(a[x.name], a[meanCol], marker='^')
plt.xlabel(x.name)
plt.ylabel(meanCol)

plt.subplot(132)
sumCol = y.name + '_sum'
plt.plot(a[x.name], a[sumCol], marker='^')
plt.xlabel(x.name)
plt.ylabel(sumCol)

plt.subplot(133)
plt.plot(a[x.name], a['sum_pct'], marker='^')
plt.xlabel(x.name)
plt.ylabel('sum_pct')
plt.tight_layout()
plt.show()

display(stats)
# Out:
#     LACERTE_NET_BILL   freq  freq_pct  ATTEMPTS_mean  ATTEMPTS_sum   sum_pct
# 0              20000  14792  0.988506       3.453286         51081  0.984087
# 1              19000  14708  0.982892       3.444928         50668  0.976130
# 2              18000  14585  0.974673       3.443469         50223  0.967557
# 3              17000  14431  0.964381       3.442242         49675  0.957000
# 4              16000  14254  0.952553       3.435667         48972  0.943457
# 5              15000  14046  0.938653       3.430728         48188  0.928353
# 6              14000  13761  0.919607       3.423952         47117  0.907720
# 7              13000  13433  0.897688       3.414799         45871  0.883715
# 8              12000  13108  0.875969       3.397315         44532  0.857919
# 9              11000  12578  0.840551       3.388059         42615  0.820988
# 10             10000  12074  0.806870       3.385539         40877  0.787505
# 11              9000  11535  0.770850       3.375466         38936  0.750111
# 12              8000  10607  0.708835       3.360611         35646  0.686728
# 13              7000   9543  0.637731       3.358273         32048  0.617412
# 14              6000   8410  0.562016       3.281213         27595  0.531624
# 15              5000   6131  0.409717       3.150546         19316  0.372127
# 16              4000   2379  0.158982       3.267339          7773  0.149749
# 17              3000    908  0.060679       2.937225          2667  0.051380
# 18              2000    275  0.018377       2.069091           569  0.010962
# 19              1000     81  0.005413       0.962963            78  0.001503

# %%
display(np.sort(df.columns))
# Out:
# array(['ATTEMPTS', 'ATTEMPTS_CHANGE', 'ATTEMPTS_CHANGE_PCT', 'AT_RISK',
#        'AT_RISK_COUNT', 'AT_RISK_REASON', 'BILL_COST_RATIO',
#        'BILL_COST_RATIO_1015', 'BILL_COST_RATIO_1015_CHANGE',
#        'BILL_COST_RATIO_CHANGE', 'BILL_FEE_RATIO', 'BILL_FEE_RATIO_1015',
#        'BILL_FEE_RATIO_1015_CHANGE', 'BILL_FEE_RATIO_CHANGE',
#        'BILL_INCOME_RATIO', 'BILL_INCOME_RATIO_1015',
#        'BILL_INCOME_RATIO_1015_CHANGE', 'BILL_INCOME_RATIO_CHANGE',
#        'BIZ_EXT_COUNT', 'BIZ_EXT_COUNT_CHANGE', 'BIZ_EXT_COUNT_CHANGE_PCT',
#        'BIZ_IIT_RATIO', 'BIZ_IIT_RATIO_1015', 'BIZ_IIT_RATIO_1015_CHANGE',
#        'BIZ_IIT_RATIO_CHANGE', 'BIZ_STATES_0415', 'BIZ_STATES_0415_CHANGE',
#        'BIZ_STATES_1015', 'BIZ_STATES_1015_CHANGE', 'CAN', 'COHORT',
#        'COST_PER_UNIT_0415', 'COST_PER_UNIT_0415_CHANGE',
#        'COST_PER_UNIT_0415_CHANGE_PCT', 'COST_PER_UNIT_1015',
#        'COST_PER_UNIT_1015_CHANGE', 'COST_PER_UNIT_1015_CHANGE_PCT',
#        'DISCOUNT', 'DOWNGRADE', 'EFE_TOTAL_FED_0415',
#        'EFE_TOTAL_FED_0415_CHANGE', 'EFE_TOTAL_FED_0415_CHANGE_PCT',
#        'EFE_TOTAL_FED_1015', 'EFE_TOTAL_FED_1015_CHANGE',
#        'EFE_TOTAL_FED_1015_CHANGE_PCT', 'EFE_TOTAL_STATE_0415',
#        'EFE_TOTAL_STATE_0415_CHANGE', 'EFE_TOTAL_STATE_0415_CHANGE_PCT',
#        'EFE_TOTAL_STATE_1015', 'EFE_TOTAL_STATE_1015_CHANGE',
#        'EFE_TOTAL_STATE_1015_CHANGE_PCT', 'EXT_COUNT', 'EXT_COUNT_CHANGE',
#        'EXT_COUNT_CHANGE_PCT', 'FED_BIZ_0415', 'FED_BIZ_0415_CHANGE',
#        'FED_BIZ_0415_CHANGE_PCT', 'FED_BIZ_1015', 'FED_BIZ_1015_CHANGE',
#        'FED_BIZ_1015_CHANGE_PCT', 'FED_IIT_0415', 'FED_IIT_0415_CHANGE',
#        'FED_IIT_0415_CHANGE_PCT', 'FED_IIT_1015', 'FED_IIT_1015_CHANGE',
#        'FED_IIT_1015_CHANGE_PCT', 'FED_REJECTED_BIZ_0415',
#        'FED_REJECTED_BIZ_1015', 'FED_REJECTED_IIT_0415',
#        'FED_REJECTED_IIT_0415_CHANGE', 'FED_REJECTED_IIT_0415_CHANGE_PCT',
#        'FED_REJECTED_IIT_1015', 'FED_REJECTED_IIT_1015_CHANGE',
#        'FED_REJECTED_IIT_1015_CHANGE_PCT', 'FED_REJECTED_RT_0415',
#        'FED_REJECTED_RT_0415_CHANGE', 'FED_REJECTED_RT_0415_CHANGE_PCT',
#        'FED_REJECTED_RT_1015', 'FED_REJECTED_RT_1015_CHANGE',
#        'FED_REJECTED_RT_1015_CHANGE_PCT', 'FED_RT_0415',
#        'FED_RT_0415_CHANGE', 'FED_RT_0415_CHANGE_PCT', 'FED_RT_1015',
#        'FED_RT_1015_CHANGE', 'FED_RT_1015_CHANGE_PCT',
#        'FIXED_PRICE_ENTITLEMENT', 'FIXED_PRICE_ENTITLEMENT_CHANGE',
#        'HAS_AUTO_RENEW', 'HAS_AUTO_RENEW_CHANGE', 'HAS_BNA',
#        'HAS_BNA_CHANGE', 'HAS_DPP', 'HAS_DPP_CHANGE', 'HAS_EASYACCT',
#        'HAS_EASYACCT_CHANGE', 'HAS_LAC200', 'HAS_LAC200_CHANGE',
#        'HAS_LACERTE_LIBRARY', 'HAS_LACERTE_LIBRARY_CHANGE',
#        'IIT_EXT_COUNT', 'IIT_EXT_COUNT_CHANGE', 'IIT_EXT_COUNT_CHANGE_PCT',
#        'IIT_REFUND_CNT_0415', 'IIT_REFUND_CNT_0415_CHANGE',
#        'IIT_REFUND_CNT_0415_CHANGE_PCT', 'IIT_REFUND_CNT_1015',
#        'IIT_REFUND_CNT_1015_CHANGE', 'IIT_REFUND_CNT_1015_CHANGE_PCT',
#        'IIT_STATES_0415', 'IIT_STATES_0415_CHANGE', 'IIT_STATES_1015',
#        'IIT_STATES_1015_CHANGE', 'INBOUND_CALL_COUNT',
#        'INBOUND_CALL_COUNT_CHANGE', 'INBOUND_CALL_HIGH_COUNT',
#        'INBOUND_CALL_HIGH_COUNT_CHANGE', 'INBOUND_CHAT_COUNT',
#        'INBOUND_CHAT_COUNT_CHANGE', 'INBOUND_CHAT_HIGH_COUNT',
#        'INBOUND_CHAT_HIGH_COUNT_CHANGE', 'INBOUND_COUNT',
#        'INBOUND_COUNT_CHANGE', 'INBOUND_HIGH_COUNT',
#        'INBOUND_HIGH_COUNT_CHANGE', 'IS_DP', 'IS_DP_CHANGE', 'IS_EMPLOYEE',
#        'IS_PM', 'IS_PM_CHANGE', 'IS_RT', 'IS_RT_CHANGE', 'LACERTE_CHANNEL',
#        'LACERTE_DISCOUNT', 'LACERTE_NET_BILL', 'LACERTE_NET_BILL_CHANGE',
#        'LACERTE_NET_BILL_CHANGE_PCT', 'LACERTE_NET_BILL_DISCOUNT_PCT',
#        'LACERTE_NET_BILL_PRE_DISCOUNT', 'LACERTE_TOTAL_BILL',
#        'LACERTE_TOTAL_BILL_1015', 'LACERTE_TOTAL_BILL_1015_CHANGE',
#        'LACERTE_TOTAL_BILL_1015_CHANGE_PCT', 'LACERTE_TOTAL_BILL_CHANGE',
#        'LACERTE_TOTAL_BILL_CHANGE_PCT', 'LACERTE_TOTAL_BILL_DISCOUNT_PCT',
#        'LACERTE_TOTAL_BILL_PRE_DISCOUNT', 'LAC_200_CNT',
#        'LAC_200_CNT_CHANGE', 'LOST', 'MULTI_YEAR_ENTITLEMENT', 'NET_BILL',
#        'NET_BILL_CHANGE', 'NET_BILL_CHANGE_PCT', 'NET_BILL_DISCOUNT_PCT',
#        'NET_BILL_PRE_DISCOUNT', 'NEXT_ATTEMPTS', 'NEXT_AT_RISK',
#        'NEXT_AT_RISK_REASON', 'NEXT_DOWNGRADE', 'NEXT_LACERTE_NET_BILL',
#        'NEXT_LACERTE_TOTAL_BILL', 'NEXT_LACERTE_TOTAL_BILL_1015',
#        'NEXT_LOST', 'NEXT_NET_BILL', 'NEXT_ORDER_MONTH',
#        'NEXT_ORDER_MONTH_CHANGE', 'NEXT_PRODUCT_FAMILY',
#        'NEXT_PRODUCT_GROUP', 'NEXT_PRODUCT_SEGMENT', 'NEXT_PS_NET_BILL',
#        'NEXT_PS_TOTAL_BILL', 'NEXT_PS_TOTAL_BILL_1015', 'NEXT_TOTAL_BILL',
#        'NEXT_TOTAL_BILL_1015', 'NEXT_TOTAL_BILL_CHANGE_PCT',
#        'ONE_TIME_ENTITLEMENT', 'ONE_TIME_ENTITLEMENT_CHANGE', 'ORDER_DATE',
#        'ORDER_MONTH', 'ORDER_MONTH_CHANGE', 'PPR_CLICK', 'PPR_CLICK_1015',
#        'PPR_CLICK_PCT', 'PPR_CLICK_PCT_1015', 'PPR_CLICK_PCT_1015_CHANGE',
#        'PPR_CLICK_PCT_CHANGE', 'PPR_FED', 'PPR_FED_1015',
#        'PPR_FED_1015_CHANGE', 'PPR_FED_1015_CHANGE_PCT', 'PPR_FED_BIZ',
#        'PPR_FED_BIZ_1015', 'PPR_FED_BIZ_1015_CHANGE',
#        'PPR_FED_BIZ_1015_CHANGE_PCT', 'PPR_FED_BIZ_CHANGE',
#        'PPR_FED_BIZ_CHANGE_PCT', 'PPR_FED_BIZ_NGA_CLICK',
#        'PPR_FED_BIZ_NGA_CLICK_1015', 'PPR_FED_BIZ_NGA_CLICK_1015_CHANGE',
#        'PPR_FED_BIZ_NGA_CLICK_1015_CHANGE_PCT',
#        'PPR_FED_BIZ_NGA_CLICK_CHANGE', 'PPR_FED_BIZ_NGA_CLICK_CHANGE_PCT',
#        'PPR_FED_CHANGE', 'PPR_FED_CHANGE_PCT', 'PPR_FED_IIT',
#        'PPR_FED_IIT_1015', 'PPR_FED_IIT_1015_CHANGE',
#        'PPR_FED_IIT_1015_CHANGE_PCT', 'PPR_FED_IIT_CHANGE',
#        'PPR_FED_IIT_CHANGE_PCT', 'PPR_FED_IIT_NGA_CLICK',
#        'PPR_FED_IIT_NGA_CLICK_1015', 'PPR_FED_IIT_NGA_CLICK_1015_CHANGE',
#        'PPR_FED_IIT_NGA_CLICK_1015_CHANGE_PCT',
#        'PPR_FED_IIT_NGA_CLICK_CHANGE', 'PPR_FED_IIT_NGA_CLICK_CHANGE_PCT',
#        'PPR_NGA_CLICK', 'PPR_NGA_CLICK_1015', 'PPR_NGA_CLICK_1015_CHANGE',
#        'PPR_NGA_CLICK_1015_CHANGE_PCT', 'PPR_NGA_CLICK_CHANGE',
#        'PPR_NGA_CLICK_CHANGE_PCT', 'PPR_NGA_FED_CLICK',
#        'PPR_NGA_FED_CLICK_1015', 'PPR_NGA_FED_CLICK_1015_CHANGE',
#        'PPR_NGA_FED_CLICK_1015_CHANGE_PCT', 'PPR_NGA_FED_CLICK_CHANGE',
#        'PPR_NGA_FED_CLICK_CHANGE_PCT', 'PPR_NGA_STATE_CLICK',
#        'PPR_NGA_STATE_CLICK_1015', 'PPR_NGA_STATE_CLICK_1015_CHANGE',
#        'PPR_NGA_STATE_CLICK_1015_CHANGE_PCT', 'PPR_NGA_STATE_CLICK_CHANGE',
#        'PPR_NGA_STATE_CLICK_CHANGE_PCT', 'PPR_SIEBEL_CLICK',
#        'PPR_SIEBEL_CLICK_1015', 'PPR_SIEBEL_CLICK_1015_CHANGE',
#        'PPR_SIEBEL_CLICK_1015_CHANGE_PCT', 'PPR_SIEBEL_CLICK_CHANGE',
#        'PPR_SIEBEL_CLICK_CHANGE_PCT', 'PPR_STATE', 'PPR_STATE_1015',
#        'PPR_STATE_1015_CHANGE', 'PPR_STATE_1015_CHANGE_PCT',
#        'PPR_STATE_BIZ', 'PPR_STATE_BIZ_1015', 'PPR_STATE_BIZ_1015_CHANGE',
#        'PPR_STATE_BIZ_1015_CHANGE_PCT', 'PPR_STATE_BIZ_CHANGE',
#        'PPR_STATE_BIZ_CHANGE_PCT', 'PPR_STATE_BIZ_NGA_CLICK',
#        'PPR_STATE_BIZ_NGA_CLICK_1015',
#        'PPR_STATE_BIZ_NGA_CLICK_1015_CHANGE',
#        'PPR_STATE_BIZ_NGA_CLICK_1015_CHANGE_PCT',
#        'PPR_STATE_BIZ_NGA_CLICK_CHANGE',
#        'PPR_STATE_BIZ_NGA_CLICK_CHANGE_PCT', 'PPR_STATE_CHANGE',
#        'PPR_STATE_CHANGE_PCT', 'PPR_STATE_IIT', 'PPR_STATE_IIT_1015',
#        'PPR_STATE_IIT_1015_CHANGE', 'PPR_STATE_IIT_1015_CHANGE_PCT',
#        'PPR_STATE_IIT_CHANGE', 'PPR_STATE_IIT_CHANGE_PCT',
#        'PPR_STATE_IIT_NGA_CLICK', 'PPR_STATE_IIT_NGA_CLICK_1015',
#        'PPR_STATE_IIT_NGA_CLICK_1015_CHANGE',
#        'PPR_STATE_IIT_NGA_CLICK_1015_CHANGE_PCT',
#        'PPR_STATE_IIT_NGA_CLICK_CHANGE',
#        'PPR_STATE_IIT_NGA_CLICK_CHANGE_PCT', 'PREV_ATTEMPTS',
#        'PREV_BILL_COST_RATIO', 'PREV_BILL_COST_RATIO_1015',
#        'PREV_BILL_FEE_RATIO', 'PREV_BILL_FEE_RATIO_1015',
#        'PREV_BILL_INCOME_RATIO', 'PREV_BILL_INCOME_RATIO_1015',
#        'PREV_BIZ_EXT_COUNT', 'PREV_BIZ_IIT_RATIO',
#        'PREV_BIZ_IIT_RATIO_1015', 'PREV_BIZ_STATES_0415',
#        'PREV_BIZ_STATES_1015', 'PREV_COST_PER_UNIT_0415',
#        'PREV_COST_PER_UNIT_1015', 'PREV_EFE_TOTAL_FED_0415',
#        'PREV_EFE_TOTAL_FED_1015', 'PREV_EFE_TOTAL_STATE_0415',
#        'PREV_EFE_TOTAL_STATE_1015', 'PREV_EXT_COUNT', 'PREV_FED_BIZ_0415',
#        'PREV_FED_BIZ_1015', 'PREV_FED_IIT_0415', 'PREV_FED_IIT_1015',
#        'PREV_FED_REJECTED_IIT_0415', 'PREV_FED_REJECTED_IIT_1015',
#        'PREV_FED_REJECTED_RT_0415', 'PREV_FED_REJECTED_RT_1015',
#        'PREV_FED_RT_0415', 'PREV_FED_RT_1015', 'PREV_HAS_AUTO_RENEW',
#        'PREV_HAS_BNA', 'PREV_HAS_DPP', 'PREV_HAS_EASYACCT',
#        'PREV_HAS_LAC200', 'PREV_HAS_LACERTE_LIBRARY', 'PREV_IIT_EXT_COUNT',
#        'PREV_IIT_REFUND_CNT_0415', 'PREV_IIT_REFUND_CNT_1015',
#        'PREV_IIT_STATES_0415', 'PREV_IIT_STATES_1015',
#        'PREV_INBOUND_CALL_COUNT', 'PREV_INBOUND_CALL_HIGH_COUNT',
#        'PREV_INBOUND_CHAT_COUNT', 'PREV_INBOUND_CHAT_HIGH_COUNT',
#        'PREV_INBOUND_COUNT', 'PREV_INBOUND_HIGH_COUNT',
#        'PREV_LACERTE_NET_BILL', 'PREV_LACERTE_TOTAL_BILL',
#        'PREV_LACERTE_TOTAL_BILL_1015', 'PREV_LAC_200_CNT', 'PREV_NET_BILL',
#        'PREV_ORDER_MONTH', 'PREV_PPR_CLICK_PCT', 'PREV_PPR_CLICK_PCT_1015',
#        'PREV_PPR_FED', 'PREV_PPR_FED_1015', 'PREV_PPR_FED_BIZ',
#        'PREV_PPR_FED_BIZ_1015', 'PREV_PPR_FED_BIZ_NGA_CLICK',
#        'PREV_PPR_FED_BIZ_NGA_CLICK_1015', 'PREV_PPR_FED_IIT',
#        'PREV_PPR_FED_IIT_1015', 'PREV_PPR_FED_IIT_NGA_CLICK',
#        'PREV_PPR_FED_IIT_NGA_CLICK_1015', 'PREV_PPR_NGA_CLICK',
#        'PREV_PPR_NGA_CLICK_1015', 'PREV_PPR_NGA_FED_CLICK',
#        'PREV_PPR_NGA_FED_CLICK_1015', 'PREV_PPR_NGA_STATE_CLICK',
#        'PREV_PPR_NGA_STATE_CLICK_1015', 'PREV_PPR_SIEBEL_CLICK',
#        'PREV_PPR_SIEBEL_CLICK_1015', 'PREV_PPR_STATE',
#        'PREV_PPR_STATE_1015', 'PREV_PPR_STATE_BIZ',
#        'PREV_PPR_STATE_BIZ_1015', 'PREV_PPR_STATE_BIZ_NGA_CLICK',
#        'PREV_PPR_STATE_BIZ_NGA_CLICK_1015', 'PREV_PPR_STATE_IIT',
#        'PREV_PPR_STATE_IIT_1015', 'PREV_PPR_STATE_IIT_NGA_CLICK',
#        'PREV_PPR_STATE_IIT_NGA_CLICK_1015', 'PREV_PRODUCT_FAMILY',
#        'PREV_PRODUCT_GROUP', 'PREV_PRODUCT_SEGMENT', 'PREV_PS_NET_BILL',
#        'PREV_PS_TOTAL_BILL', 'PREV_PS_TOTAL_BILL_1015',
#        'PREV_REP_CLICK_PCT', 'PREV_REP_CLICK_PCT_1015', 'PREV_REP_FED',
#        'PREV_REP_FED_1015', 'PREV_REP_FED_BIZ', 'PREV_REP_FED_BIZ_1015',
#        'PREV_REP_FED_BIZ_CLICK', 'PREV_REP_FED_BIZ_CLICK_1015',
#        'PREV_REP_FED_IIT', 'PREV_REP_FED_IIT_1015',
#        'PREV_REP_FED_IIT_CLICK', 'PREV_REP_FED_IIT_CLICK_1015',
#        'PREV_REP_STATE', 'PREV_REP_STATE_1015', 'PREV_REP_STATE_BIZ',
#        'PREV_REP_STATE_BIZ_1015', 'PREV_REP_STATE_BIZ_CLICK',
#        'PREV_REP_STATE_BIZ_CLICK_1015', 'PREV_REP_STATE_IIT',
#        'PREV_REP_STATE_IIT_1015', 'PREV_REP_STATE_IIT_CLICK',
#        'PREV_REP_STATE_IIT_CLICK_1015', 'PREV_STATE_BIZ_0415',
#        'PREV_STATE_BIZ_1015', 'PREV_STATE_IIT_0415', 'PREV_STATE_IIT_1015',
#        'PREV_SUM_IIT_AGI_0415', 'PREV_SUM_IIT_AGI_1015', 'PREV_TOTAL_BILL',
#        'PREV_TOTAL_BILL_1015', 'PREV_TOTAL_INBOUND_COUNT', 'PREV_UNL_FED',
#        'PREV_UNL_FED_BENEFIT', 'PREV_UNL_FED_BIZ', 'PREV_UNL_FED_CORP',
#        'PREV_UNL_FED_ESTATE', 'PREV_UNL_FED_EXEMPT_ORG',
#        'PREV_UNL_FED_FID', 'PREV_UNL_FED_GIFT', 'PREV_UNL_FED_IIT',
#        'PREV_UNL_FED_PARTNER', 'PREV_UNL_FED_SCORP', 'PREV_UNL_STATE',
#        'PREV_UNL_STATE_BIZ', 'PREV_UNL_STATE_CORP', 'PREV_UNL_STATE_FID',
#        'PREV_UNL_STATE_IIT', 'PREV_UNL_STATE_PARTNER',
#        'PREV_UNL_STATE_SCORP', 'PRODUCT_FAMILY', 'PRODUCT_GROUP',
#        'PRODUCT_SEGMENT', 'PS_CHANNEL', 'PS_DISCOUNT', 'PS_NET_BILL',
#        'PS_NET_BILL_CHANGE', 'PS_NET_BILL_CHANGE_PCT',
#        'PS_NET_BILL_DISCOUNT_PCT', 'PS_NET_BILL_PRE_DISCOUNT',
#        'PS_TOTAL_BILL', 'PS_TOTAL_BILL_1015', 'PS_TOTAL_BILL_1015_CHANGE',
#        'PS_TOTAL_BILL_1015_CHANGE_PCT', 'PS_TOTAL_BILL_CHANGE',
#        'PS_TOTAL_BILL_CHANGE_PCT', 'PS_TOTAL_BILL_DISCOUNT_PCT',
#        'PS_TOTAL_BILL_PRE_DISCOUNT', 'PS_TOTAL_BILL_PRE_DISCOUNT_1015',
#        'REP_CLICK', 'REP_CLICK_1015', 'REP_CLICK_PCT',
#        'REP_CLICK_PCT_1015', 'REP_CLICK_PCT_1015_CHANGE',
#        'REP_CLICK_PCT_CHANGE', 'REP_FED', 'REP_FED_1015',
#        'REP_FED_1015_CHANGE', 'REP_FED_1015_CHANGE_PCT', 'REP_FED_BIZ',
#        'REP_FED_BIZ_1015', 'REP_FED_BIZ_1015_CHANGE',
#        'REP_FED_BIZ_1015_CHANGE_PCT', 'REP_FED_BIZ_CHANGE',
#        'REP_FED_BIZ_CHANGE_PCT', 'REP_FED_BIZ_CLICK',
#        'REP_FED_BIZ_CLICK_1015', 'REP_FED_BIZ_CLICK_1015_CHANGE',
#        'REP_FED_BIZ_CLICK_1015_CHANGE_PCT', 'REP_FED_BIZ_CLICK_CHANGE',
#        'REP_FED_BIZ_CLICK_CHANGE_PCT', 'REP_FED_CHANGE',
#        'REP_FED_CHANGE_PCT', 'REP_FED_IIT', 'REP_FED_IIT_1015',
#        'REP_FED_IIT_1015_CHANGE', 'REP_FED_IIT_1015_CHANGE_PCT',
#        'REP_FED_IIT_CHANGE', 'REP_FED_IIT_CHANGE_PCT', 'REP_FED_IIT_CLICK',
#        'REP_FED_IIT_CLICK_1015', 'REP_FED_IIT_CLICK_1015_CHANGE',
#        'REP_FED_IIT_CLICK_1015_CHANGE_PCT', 'REP_FED_IIT_CLICK_CHANGE',
#        'REP_FED_IIT_CLICK_CHANGE_PCT', 'REP_STATE', 'REP_STATE_1015',
#        'REP_STATE_1015_CHANGE', 'REP_STATE_1015_CHANGE_PCT',
#        'REP_STATE_BIZ', 'REP_STATE_BIZ_1015', 'REP_STATE_BIZ_1015_CHANGE',
#        'REP_STATE_BIZ_1015_CHANGE_PCT', 'REP_STATE_BIZ_CHANGE',
#        'REP_STATE_BIZ_CHANGE_PCT', 'REP_STATE_BIZ_CLICK',
#        'REP_STATE_BIZ_CLICK_1015', 'REP_STATE_BIZ_CLICK_1015_CHANGE',
#        'REP_STATE_BIZ_CLICK_1015_CHANGE_PCT', 'REP_STATE_BIZ_CLICK_CHANGE',
#        'REP_STATE_BIZ_CLICK_CHANGE_PCT', 'REP_STATE_CHANGE',
#        'REP_STATE_CHANGE_PCT', 'REP_STATE_IIT', 'REP_STATE_IIT_1015',
#        'REP_STATE_IIT_1015_CHANGE', 'REP_STATE_IIT_1015_CHANGE_PCT',
#        'REP_STATE_IIT_CHANGE', 'REP_STATE_IIT_CHANGE_PCT',
#        'REP_STATE_IIT_CLICK', 'REP_STATE_IIT_CLICK_1015',
#        'REP_STATE_IIT_CLICK_1015_CHANGE',
#        'REP_STATE_IIT_CLICK_1015_CHANGE_PCT', 'REP_STATE_IIT_CLICK_CHANGE',
#        'REP_STATE_IIT_CLICK_CHANGE_PCT', 'REP_STATE_ONLY_BIZ',
#        'REP_STATE_ONLY_BIZ_1015', 'REP_STATE_ONLY_BIZ_CLICK',
#        'REP_STATE_ONLY_BIZ_CLICK_1015', 'REP_STATE_ONLY_IIT',
#        'REP_STATE_ONLY_IIT_1015', 'REP_STATE_ONLY_IIT_CLICK',
#        'REP_STATE_ONLY_IIT_CLICK_1015', 'START_YEAR', 'STATE_BIZ_0415',
#        'STATE_BIZ_0415_CHANGE', 'STATE_BIZ_0415_CHANGE_PCT',
#        'STATE_BIZ_1015', 'STATE_BIZ_1015_CHANGE',
#        'STATE_BIZ_1015_CHANGE_PCT', 'STATE_COST', 'STATE_FEE',
#        'STATE_IIT_0415', 'STATE_IIT_0415_CHANGE',
#        'STATE_IIT_0415_CHANGE_PCT', 'STATE_IIT_1015',
#        'STATE_IIT_1015_CHANGE', 'STATE_IIT_1015_CHANGE_PCT',
#        'STATE_INCOME', 'STATE_RESIDE', 'SUM_IIT_AGI_0415',
#        'SUM_IIT_AGI_0415_CHANGE', 'SUM_IIT_AGI_0415_CHANGE_PCT',
#        'SUM_IIT_AGI_1015', 'SUM_IIT_AGI_1015_CHANGE',
#        'SUM_IIT_AGI_1015_CHANGE_PCT', 'TOTAL_BILL', 'TOTAL_BILL_1015',
#        'TOTAL_BILL_1015_CHANGE', 'TOTAL_BILL_1015_CHANGE_PCT',
#        'TOTAL_BILL_CHANGE', 'TOTAL_BILL_CHANGE_PCT',
#        'TOTAL_BILL_DISCOUNT_PCT', 'TOTAL_BILL_PRE_DISCOUNT',
#        'TOTAL_BILL_PRE_DISCOUNT_1015', 'TOTAL_INBOUND_COUNT',
#        'TOTAL_INBOUND_COUNT_CHANGE', 'UNL_FED', 'UNL_FED_BENEFIT',
#        'UNL_FED_BENEFIT_CHANGE', 'UNL_FED_BIZ', 'UNL_FED_BIZ_CHANGE',
#        'UNL_FED_CHANGE', 'UNL_FED_CORP', 'UNL_FED_CORP_CHANGE',
#        'UNL_FED_ESTATE', 'UNL_FED_ESTATE_CHANGE', 'UNL_FED_EXEMPT_ORG',
#        'UNL_FED_EXEMPT_ORG_CHANGE', 'UNL_FED_FID', 'UNL_FED_FID_CHANGE',
#        'UNL_FED_GIFT', 'UNL_FED_GIFT_CHANGE', 'UNL_FED_IIT',
#        'UNL_FED_IIT_CHANGE', 'UNL_FED_PARTNER', 'UNL_FED_PARTNER_CHANGE',
#        'UNL_FED_SCORP', 'UNL_FED_SCORP_CHANGE', 'UNL_STATE',
#        'UNL_STATE_BIZ', 'UNL_STATE_BIZ_CHANGE', 'UNL_STATE_CHANGE',
#        'UNL_STATE_CORP', 'UNL_STATE_CORP_CHANGE', 'UNL_STATE_FID',
#        'UNL_STATE_FID_CHANGE', 'UNL_STATE_IIT', 'UNL_STATE_IIT_CHANGE',
#        'UNL_STATE_PARTNER', 'UNL_STATE_PARTNER_CHANGE', 'UNL_STATE_SCORP',
#        'UNL_STATE_SCORP_CHANGE'], dtype=object)

# %%
x = df.LACERTE_NET_BILL_DISCOUNT_PCT
y = df.AT_RISK
stats = greaterThanProbs(x, y, binSize=0.02)
a = stats.sort_values(x.name)

plt.figure(figsize=(16,6))
plt.plot(a[x.name], a.prob, marker='^')
plt.grid(axis='y')
plt.xlabel(x.name)
plt.ylabel(y.name+' Probability')
plt.tight_layout()
plt.show()

display(stats)
# Out:
#     LACERTE_NET_BILL_DISCOUNT_PCT    bucket   freq  freq_pct      prob
# 0                            0.00  >= 0.000  14964  1.000000  0.043571
# 1                            0.02  >= 0.020  14402  0.962443  0.045271
# 2                            0.04  >= 0.040  14384  0.961240  0.045328
# 3                            0.06  >= 0.060  14359  0.959570  0.045407
# 4                            0.08  >= 0.080  14300  0.955627  0.045594
# 5                            0.10  >= 0.100  14165  0.946605  0.046029
# 6                            0.12  >= 0.120  13313  0.889669  0.048975
# 7                            0.14  >= 0.140   8818  0.589281  0.073940
# 8                            0.16  >= 0.160   7138  0.477011  0.091342
# 9                            0.18  >= 0.180   6497  0.434175  0.100354
# 10                           0.20  >= 0.200   5532  0.369687  0.117860
# 11                           0.22  >= 0.220   4978  0.332665  0.130976
# 12                           0.24  >= 0.240   4504  0.300989  0.144760
# 13                           0.26  >= 0.260   4155  0.277666  0.156919
# 14                           0.28  >= 0.280   3894  0.260225  0.167437
# 15                           0.30  >= 0.300   3522  0.235365  0.185122
# 16                           0.32  >= 0.320   2908  0.194333  0.224209
# 17                           0.34  >= 0.340   2678  0.178963  0.243465
# 18                           0.36  >= 0.360   2452  0.163860  0.265905
# 19                           0.38  >= 0.380   2267  0.151497  0.287605
# 20                           0.40  >= 0.400   2092  0.139802  0.311663
# 21                           0.42  >= 0.420   1524  0.101844  0.427822
# 22                           0.44  >= 0.440   1353  0.090417  0.481892
# 23                           0.46  >= 0.460   1240  0.082866  0.525806
# 24                           0.48  >= 0.480   1116  0.074579  0.584229
# 25                           0.50  >= 0.500   1022  0.068297  0.637965
# 26                           0.52  >= 0.520    736  0.049185  0.885870
# 27                           0.54  >= 0.540    654  0.043705  0.996942
# 28                           0.56  >= 0.560    584  0.039027  1.116438
# 29                           0.58  >= 0.580    529  0.035352  1.232514
# 30                           0.60  >= 0.600    498  0.033280  1.309237
# 31                           0.62  >= 0.620    334  0.022320  1.952096
# 32                           0.64  >= 0.640    306  0.020449  2.130719
# 33                           0.66  >= 0.660    285  0.019046  2.287719
# 34                           0.68  >= 0.680    250  0.016707  2.608000
# 35                           0.70  >= 0.700    195  0.013031  3.343590
# 36                           0.72  >= 0.720    175  0.011695  3.725714
# 37                           0.74  >= 0.740    144  0.009623  4.527778
# 38                           0.76  >= 0.760    125  0.008353  5.216000
# 39                           0.78  >= 0.780    112  0.007485  5.821429
# 40                           0.80  >= 0.800    104  0.006950  6.269231
# 41                           0.82  >= 0.820     88  0.005881  7.409091
# 42                           0.84  >= 0.840     82  0.005480  7.951220
# 43                           0.86  >= 0.860     78  0.005213  8.358974
# 44                           0.88  >= 0.880     77  0.005146  8.467532
# 45                           0.90  >= 0.900     77  0.005146  8.467532
# 46                           0.92  >= 0.920     75  0.005012  8.693333
# 47                           0.94  >= 0.940     75  0.005012  8.693333
# 48                           0.96  >= 0.960     75  0.005012  8.693333
# 49                           0.98  >= 0.980     72  0.004812  9.055556

# %%
def inBinProbs(x, y, binSize, positiveClass=True, minx=None, maxx=None, minCnt=20):
    """
    both x is numeric and y is categorical. returns y's probabilities in each x bin
    """
    assert(y is not None)
    
    binDF = pd.concat([x,y], axis=1, ignore_index=True)
    binDF.columns = ['x', 'y']
    if minx is None:
        minx = binDF.x.min()
    if maxx is None:
        maxx = binDF.x.max()

    minx, maxx = [minx, maxx]
    bins = np.arange(minx, maxx*1.0001, binSize)
    rsDF = pd.DataFrame(bins, columns=[x.name])
    rsDF['bucket'] = rsDF[x.name].map(lambda x: '>= {:.3f}'.format(x))
    
    freqCol = 'freq'
    rsDF[freqCol] = [binDF.loc[binDF.x >= thresh, 'y'].shape[0] for thresh in bins]
    rsDF['freq_pct'] = rsDF[freqCol]/x.shape[0]
    
    def prob(bmin, bmax):
        aa = binDF[(binDF.x >= bmin) & (binDF.x < bmax)]
        if aa.shape[0] == 0:
            return 0.0
        
        aaPos = binDF[binDF.y == positiveClass]
        return float(aaPos.shape[0])/float(aa.shape[0])

    rsDF['prob'] = [prob(bins[i], bins[i+1]) for i in range(len(bins)-1)]
    
    rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
    return rsDF

# %%
x = df.ATTEMPTS
y = df.AT_RISK
stats = inBinProbs(x, y, binSize=1)
a = stats.sort_values(x.name)

plt.figure(figsize=(16,6))
plt.plot(a[x.name], a.prob, marker='^')
plt.grid(axis='y')
plt.xlabel(x.name)
plt.ylabel(y.name+' Probability')
plt.tight_layout()
plt.show()

display(stats)
# Out:
# > <ipython-input-15-8dd3dd0a0f1c>(33)inBinProbs()
#      31
#      32     Pdb().set_trace()
# ---> 33     rsDF['prob'] = [prob(bins[i], bins[i+1]) for i in range(len(bins)-1)]
#      34
#      35     rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
#
# ipdb> c
# > <ipython-input-15-8dd3dd0a0f1c>(25)prob()
#      23     def prob(bmin, bmax):
#      24         Pdb().set_trace()
# ---> 25         aa = binDF[binDF.x >= bmin & binDF.x < bmax]
#      26         if aa.shape[0] == 0:
#      27             return 0.0
#
# ipdb> c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/huiwang/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     882         try:
# --> 883             result = op(x, y)
#     884         except TypeError:
#
# /Users/huiwang/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#     128                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 129                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     130                                    names('rand_'), op('&')),
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/huiwang/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     900                         y = bool(y)
# --> 901                     result = lib.scalar_binop(x, y, op)
#     902                 except:
#
# pandas/_libs/lib.pyx in pandas._libs.lib.scalar_binop (pandas/_libs/lib.c:15031)()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-de3118e7874f> in <module>()
#       1 x = df.ATTEMPTS
#       2 y = df.AT_RISK
# ----> 3 stats = inBinProbs(x, y, binSize=1)
#       4 a = stats.sort_values(x.name)
#       5
#
# <ipython-input-15-8dd3dd0a0f1c> in inBinProbs(x, y, binSize, positiveClass, minx, maxx, minCnt)
#      31
#      32     Pdb().set_trace()
# ---> 33     rsDF['prob'] = [prob(bins[i], bins[i+1]) for i in range(len(bins)-1)]
#      34
#      35     rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
#
# <ipython-input-15-8dd3dd0a0f1c> in <listcomp>(.0)
#      31
#      32     Pdb().set_trace()
# ---> 33     rsDF['prob'] = [prob(bins[i], bins[i+1]) for i in range(len(bins)-1)]
#      34
#      35     rsDF = rsDF[rsDF[freqCol] >= minCnt].copy()
#
# <ipython-input-15-8dd3dd0a0f1c> in prob(bmin, bmax)
#      23     def prob(bmin, bmax):
#      24         Pdb().set_trace()
# ---> 25         aa = binDF[binDF.x >= bmin & binDF.x < bmax]
#      26         if aa.shape[0] == 0:
#      27             return 0.0
#
# /Users/huiwang/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other)
#     933                       is_integer_dtype(np.asarray(other)) else fill_bool)
#     934             return filler(self._constructor(
# --> 935                 na_op(self.values, other),
#     936                 index=self.index)).__finalize__(self)
#     937
#
# /Users/huiwang/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     903                     raise TypeError("cannot compare a dtyped [{0}] array with "
#     904                                     "a scalar of type [{1}]".format(
# --> 905                                         x.dtype, type(y).__name__))
#     906
#     907         return result
#
# TypeError: cannot compare a dtyped [int64] array with a scalar of type [bool]
